# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/raw/resume_data_1.csv')
df.head()
# Out:
#   address                                   career_objective  \
# 0     NaN  Big data analytics working and database wareho...
# 1     NaN  Fresher looking to join as a data analyst and ...
# 2     NaN                                                NaN
# 3     NaN  To obtain a position in a fast-paced business ...
# 4     NaN  Professional accountant with an outstanding wo...
#
#                                               skills  \
# 0  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1  ['Data Analysis', 'Data Analytics', 'Business ...
# 2  ['Software Development', 'Machine Learning', '...
# 3  ['accounts payables', 'accounts receivables', ...
# 4  ['Analytical reasoning', 'Compliance testing k...
#
#                         educational_institution_name  \
# 0  ['The Amity School of Engineering & Technology...
# 1  ['Delhi University - Hansraj College', 'Delhi ...
# 2    ['Birla Institute of Technology (BIT), Ranchi']
# 3  ['Martinez Adult Education, Business Training ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 34 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   address                              784 non-null    object
#  1   career_objective                     4740 non-null   object
#  2   skills                               9488 non-null   object
#  3   educational_institution_name         9460 non-null   object
#  4   degree_names                         9460 non-null   object
#  5   passing_years                        9460 non-null   object
#  6   educational_results                  9460 non-null   object
#  7   result_types                         9460 non-null   object
#  8   major_field_of_studies               9460 non-null   object
#  9   professional_company_names           9460 non-null   object
#  10  company_urls                         9460 non-null   object
# ...

# %%
# df = df.drop(columns = ['responsibilities'])

# %%
resumes = df.iloc[:, :27]
jobs = df.iloc[:, 27:]

# %%
resumes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 27 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   address                              784 non-null    object
#  1   career_objective                     4740 non-null   object
#  2   skills                               9488 non-null   object
#  3   educational_institution_name         9460 non-null   object
#  4   degree_names                         9460 non-null   object
#  5   passing_years                        9460 non-null   object
#  6   educational_results                  9460 non-null   object
#  7   result_types                         9460 non-null   object
#  8   major_field_of_studies               9460 non-null   object
#  9   professional_company_names           9460 non-null   object
#  10  company_urls                         9460 non-null   object
# ...

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ﻿job_position_name        9544 non-null   object
#  1   educationaL_requirements  9544 non-null   object
#  2   experiencere_requirement  8180 non-null   object
#  3   age_requirement           5457 non-null   object
#  4   responsibilities.1        9544 non-null   object
#  5   skills_required           7843 non-null   object
#  6   matched_score             9544 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 522.1+ KB

# %%
jobs.duplicated().sum()
# Out:
# 7655

# %%
jobs[jobs.duplicated()].head()
# Out:
#                                    ﻿job_position_name  \
# 6                                 Senior iOS Engineer
# 7                                 Senior iOS Engineer
# 33                                Senior iOS Engineer
# 58  Executive/ Senior Executive- Trade Marketing, ...
# 60                                    Executive - VAT
#
#                          educationaL_requirements experiencere_requirement  \
# 6   Bachelor of Science (BSc) in Computer Science         At least 4 years
# 7   Bachelor of Science (BSc) in Computer Science         At least 4 years
# 33  Bachelor of Science (BSc) in Computer Science         At least 4 years
# 58        Master of Business Administration (MBA)         At least 3 years
# 60                  BBA in Accounting and Finance             1 to 3 years
#
#    age_requirement                                 responsibilities.1  \
# 6              NaN  iOS Lifecycle\nRequirement Analysis\nNative Fr...
# ...

# %%
jobs.drop_duplicates()
# Out:
#                                      ﻿job_position_name  \
# 0                              Senior Software Engineer
# 1                        Machine Learning (ML) Engineer
# 2     Executive/ Senior Executive- Trade Marketing, ...
# 3                        Business Development Executive
# 4                                   Senior iOS Engineer
# ...                                                 ...
# 9483                                         HR Officer
# 9484  Intern (Generative AI Engineering - 2D/3D Imag...
# 9504             Full Stack Developer (Python,React js)
# 9506                    Management Trainee - Mechanical
# 9514                              Data Science Engineer
#
#                                educationaL_requirements  \
# 0     B.Sc in Computer Science & Engineering from a ...
# 1     M.Sc in Computer Science & Engineering or in a...
# 2               Master of Business Administration (MBA)
# 3                                       Bachelor/Honors
# ...

# %%
jobs.columns = ['position', 'education_requirement', 'experience_requirement', 'age_requirement', 'responsibilities', 'skill_required', 'matched_score']

# %%
jobs['combined'] = jobs.drop(columns=['matched_score']).apply(lambda row: " ".join(row.astype(str).values), axis=1)

# %%
jobs.head()
# Out:
#                                             position  \
# 0                           Senior Software Engineer
# 1                     Machine Learning (ML) Engineer
# 2  Executive/ Senior Executive- Trade Marketing, ...
# 3                     Business Development Executive
# 4                                Senior iOS Engineer
#
#                                education_requirement experience_requirement  \
# 0  B.Sc in Computer Science & Engineering from a ...        At least 1 year
# 1  M.Sc in Computer Science & Engineering or in a...     At least 5 year(s)
# 2            Master of Business Administration (MBA)       At least 3 years
# 3                                    Bachelor/Honors           1 to 3 years
# 4      Bachelor of Science (BSc) in Computer Science       At least 4 years
#
#       age_requirement                                   responsibilities  \
# 0                 NaN  Technical Support\nTroubleshooting\nCollaborat...
# ...

# %%
jobs['combined'].duplicated().sum()
# Out:
# 9516

# %%
jobs.duplicated().sum()
# Out:
# 7655

# %%
jobs.drop(['matched_score', 'combined'], axis=1).duplicated().sum()
# Out:
# 9516

# %%
unique_jobs = jobs.drop(columns = ['matched_score', 'combined'])
unique_jobs = unique_jobs.drop_duplicates().reset_index(drop=True)
unique_jobs['job_id'] = unique_jobs.index

# %%
resumes.columns
# Out:
# Index(['address', 'career_objective', 'skills', 'educational_institution_name',
#        'degree_names', 'passing_years', 'educational_results', 'result_types',
#        'major_field_of_studies', 'professional_company_names', 'company_urls',
#        'start_dates', 'end_dates', 'related_skils_in_job', 'positions',
#        'locations', 'extra_curricular_activity_types',
#        'extra_curricular_organization_names',
#        'extra_curricular_organization_links', 'role_positions', 'languages',
#        'proficiency_levels', 'certification_providers', 'certification_skills',
#        'online_links', 'issue_dates', 'expiry_dates'],
#       dtype='object')

# %%
resumes.duplicated().sum()
# Out:
# 9200

# %%
resumes['resume_id'] = resumes.index

# %%
# resumes = resumes.drop(columns = ['responsibilities'])

# %%
# merged = unique_jobs.merge(resumes)

# %%
# merged.head()

# %%
# merged.shape
